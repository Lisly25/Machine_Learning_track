# %% [markdown]
# **Exercise 00 for Piscine Pro AI /Machine Learning track**
#
# The goal of the exercise was to take the provided csv file, and find a way to display the data in a format that matches the sample we were given.

# %%
import pandas as pd
import seaborn as sb

# %%
from google.colab import files
uploaded = pd.read_csv("Salary_dataset.csv")

# %%
sb.set_theme()

# %%
dataframe = pd.DataFrame(data=uploaded)
sb.jointplot(data=dataframe, x='YearsExperience', y='Salary', color="#8a6c9e")
